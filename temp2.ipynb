# %%
import joblib 
from pathlib import Path
import pandas as pd
import numpy as np

# %%
data = [0,0,0,0,4,0,0.07958637244945066,0.1168384879725086,0]

# %%
test_data = pd.read_csv("artifacts/data_transformation/test.csv")
test_data
# Out:
#       gender  hypertension  heart_disease  ever_married  work_type  \
# 0          0             0              0             1          3
# 1          1             0              0             1          3
# 2          1             0              0             1          2
# 3          1             0              0             1          3
# 4          1             0              0             1          2
# ...      ...           ...            ...           ...        ...
# 1223       1             0              0             1          2
# 1224       1             0              0             1          2
# 1225       1             0              0             0          2
# 1226       0             0              0             1          2
# 1227       0             0              1             1          2
#
#       Residence_type  avg_glucose_level       bmi  smoking_status  stroke
# 0                  0           0.733081  0.392898               2       0
# 1                  0           0.184147  0.252005               3       0
# 2                  0           0.175053  0.361970               3       0
# 3                  1           0.865571  0.174112               2       0
# 4                  1           0.890269  0.295533               1       0
# ...              ...                ...       ...             ...     ...
# 1223               0           0.186225  0.241695               3       0
# 1224               1           0.109547  0.376861               2       0
# 1225               0           0.189502  0.135166               0       0
# 1226               0           0.115456  0.150057               2       1
# 1227               0           0.333164  0.199313               2       1
#
# [1228 rows x 10 columns]

# %%
test_x  = test_data.drop(['stroke'] , axis = 1)
test_x
# Out:
#       gender  hypertension  heart_disease  ever_married  work_type  \
# 0          0             0              0             1          3
# 1          1             0              0             1          3
# 2          1             0              0             1          2
# 3          1             0              0             1          3
# 4          1             0              0             1          2
# ...      ...           ...            ...           ...        ...
# 1223       1             0              0             1          2
# 1224       1             0              0             1          2
# 1225       1             0              0             0          2
# 1226       0             0              0             1          2
# 1227       0             0              1             1          2
#
#       Residence_type  avg_glucose_level       bmi  smoking_status
# 0                  0           0.733081  0.392898               2
# 1                  0           0.184147  0.252005               3
# 2                  0           0.175053  0.361970               3
# 3                  1           0.865571  0.174112               2
# 4                  1           0.890269  0.295533               1
# ...              ...                ...       ...             ...
# 1223               0           0.186225  0.241695               3
# 1224               1           0.109547  0.376861               2
# 1225               0           0.189502  0.135166               0
# 1226               0           0.115456  0.150057               2
# 1227               0           0.333164  0.199313               2
#
# [1228 rows x 9 columns]

# %%
model = joblib.load("artifacts/model_trainer/model.joblib")

# %%
model.predict(test_x)
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)
